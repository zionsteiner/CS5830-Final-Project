# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Calucating the Percentage increase in death rates

# %%
l1=[[7844,586,290,541],[8627,677,438,609],[9385,720,465,651],[10056,794,483,687],[10834,868,537,758],[11586,948,609, 821],[12192, 1072
,646, 890],[12822,1134,699,985 ],[ 13362, 1259,754,1072 ],[ 13869,1290,781, 1166],[ 14347, 1349, 806,1208 ]]

# %%
i=1
k=0
lf1=[]
lf2=[]
lf3=[]
lf4=[]
while i < len(l1):
    k1=((l1[i][0] - l1[i-1][0])/l1[i-1][0])*100
    k2=((l1[i][1] - l1[i-1][1])/l1[i-1][1])*100
    k3=((l1[i][2] - l1[i-1][2])/l1[i-1][2])*100
    k4=((l1[i][3] - l1[i-1][3])/l1[i-1][3])*100
    lf1.append(k1)
    lf2.append(k2)
    lf3.append(k3)
    lf4.append(k4)
    i=i+1

# %%
len(lf2)
# Out:
# 10

# %%
lf1.pop(1)
lf2.pop(1)
lf3.pop(1)
lf4.pop(1)
lf1
# Out:
# [9.98215196328404,
#  7.149706979222163,
#  7.7366746221161495,
#  6.941111316226693,
#  5.2304505437597095,
#  5.167322834645669,
#  4.211511464670098,
#  3.794342164346655,
#  3.4465354387482874]

# %%
ind=[308,
     339
,377
,414
,437
,480
,507
,543]

# %%
i=1
k=0
lfind=[]
while i < len(ind):
    k1=((ind[i] - ind[i-1])/ind[i-1])*100
    lfind.append(k1)
    i=i+1

# %%
lfind
# Out:
# [10.064935064935066,
#  11.209439528023598,
#  9.814323607427056,
#  5.555555555555555,
#  9.839816933638444,
#  5.625,
#  7.100591715976331]

# %%
uk=[10612,
    11329
,12107
,12868
,13729
,14576
,15464
,16060
]

# %%
i=1
k=0
lfuk=[]
while i < len(uk):
    k1=((uk[i] - uk[i-1])/uk[i-1])*100
    lfuk.append(k1)
    i=i+1

# %%
lfuk
# Out:
# [6.756502073124765,
#  6.867331626798482,
#  6.285619889320228,
#  6.691016474976687,
#  6.169422390560128,
#  6.092206366630077,
#  3.8541127780651836]

# %%
us=[22108,
    23649
,26057
,30985
,33284
,37054
,38910
,40682
]

# %%
i=1
k=0
lfus=[]
while i < len(us):
    k1=((us[i] - us[i-1])/us[i-1])*100
    lfus.append(k1)
    i=i+1

# %%
lfus
# Out:
# [6.970327483263977,
#  10.182248720876148,
#  18.912384388072304,
#  7.419719218976923,
#  11.326763610143011,
#  5.008905921088141,
#  4.554099203289643]

# %%
usall=[16690
,18777
,20608,
    22108,
    23649
,26057
,30985
,33284
,37054
,38910
,40682
]

# %%
i=1
k=0
lfusall=[]
while i < len(usall):
    k1=((usall[i] - usall[i-1])/usall[i-1])*100
    lfusall.append(k1)
    i=i+1

# %%
lfusall.pop(1)
lfusall
# Out:
# [12.504493708807669,
#  7.278726708074535,
#  6.970327483263977,
#  10.182248720876148,
#  18.912384388072304,
#  7.419719218976923,
#  11.326763610143011,
#  5.008905921088141,
#  4.554099203289643]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# df=pd.DataFrame({'x'=[40.22,36.92,37.6,37.5,38.06,41.20,36.84,40.54,38.58], 'y'=[11,13,14,15,16,17,18,19,20] })
# df1=pd.DataFrame({'x': range(1,21), 'y': np.random.randn(20) })

# %%
# Chicago
sns.set(font_scale=1)
sns.set_style('whitegrid')
plt.figure(figsize=((6,4)))
ax1=plt.plot( [11,13,14,15,16,17,18,19,20],[41.22,36.92,37.6,37.5,38.06,41.20,36.84,40.54,38.58], color='green',label="Positive Response",markersize=12,linewidth=2,linestyle='--')

ax2=plt.plot( [11,13,14,15,16,17,18,19,20], [40.22,32.92,35.2,41.76,33.21,37.96,46.3,47.02,41.73], color='red',label="Negative Response",linewidth=2,linestyle='--')
ax3=plt.plot( [11,13,14,15,16,17,18,19,20], [15.529010238907851,
 10.277777777777777,
 9.319899244332493,
 9.216589861751153,
 13.080168776371309,
 5.7835820895522385,
 11.022927689594356,
 2.4622716441620334,
 4.573643410852713], markerfacecolor='blue', marker='o',linewidth=3,markersize=5, color='skyblue', label="Increase in Covid Death cases (%)")
plt.xticks([11,13,14,15,16,17,18,19,20],fontsize=13)
plt.yticks(np.arange(0, 101, 10),fontsize=13)
plt.title(label='Illinois Response for Re-opening of Economy',fontsize=15)
plt.xlabel('April',fontsize=15)
plt.ylabel('percentage',fontsize=15)
plt.legend()
plt.savefig("chicago.pdf")
plt.show()

# %%
# florida
sns.set(font_scale=1)
sns.set_style('whitegrid')
plt.figure(figsize=((6,4)))

ax1=plt.plot( [11,13,14,15,16,17,18,19,20],[42.2,30.81,41.56,27.58,32.65,36.57,36.53,38.59,39.05], color='green',label="Positive Response",markersize=12,linewidth=2,linestyle='--')
ax2=plt.plot( [11,13,14,15,16,17,18,19,20], [35.77,35.67,34.15,39.90,40.13,37.35,48.07,46.49,36.09], color='red',label="Negative Response",linewidth=2,linestyle='--')
ax3=plt.plot( [11,13,14,15,16,17,18,19,20], [51.03448275862069,
 3.870967741935484,
 11.180124223602485,
 13.40782122905028,
 6.075533661740558,
 8.204334365325078,
 7.868383404864092,
 3.580901856763926,
 3.201024327784891], markerfacecolor='blue', marker='o',linewidth=3,markersize=5, color='skyblue', label="Increase in Covid Death cases (%)")
plt.xticks([11,13,14,15,16,17,18,19,20],fontsize=13)
plt.yticks(np.arange(0, 101, 10),fontsize=13)
plt.title(label='Florida Response for Re-opening of Economy',fontsize=15)
plt.xlabel('April',fontsize=15)
plt.ylabel('percentage',fontsize=15)
plt.legend()
plt.savefig("florida.pdf")
plt.show()

# %%
# Cali
sns.set(font_scale=1)
sns.set_style('whitegrid')
plt.figure(figsize=((6,4)))

ax1=plt.plot( [11,13,14,15,16,17,18,19,20],[32.82,40.07,38.19,35.51,38.90,35.66,38.26,31.39,39.59], color='green',label="Positive Response",markersize=12,linewidth=2,linestyle='--' )
ax2=plt.plot( [11,13,14,15,16,17,18,19,20],[41.22,37.94,39.92,33.64,42.19,44.26,45.40,48.25,41.11], color='red',label="Negative Response",linewidth=2,linestyle='--')
ax3=plt.plot( [11,13,14,15,16,17,18,19,20], [12.56931608133087,
 5.529953917050691,
 10.334788937409025,
 8.311345646437996,
 8.404384896467722,
 10.674157303370785,
 8.83248730964467,
 8.768656716417912,
 3.6020583190394513], markerfacecolor='blue', marker='o',linewidth=3,markersize=5, color='skyblue', label="Increase in Covid Death cases (%)")
plt.xticks([11,13,14,15,16,17,18,19,20],fontsize=13)
plt.yticks(np.arange(0, 101, 10),fontsize=13)
plt.title(label='California Response for Re-opening of Economy',fontsize=15)
plt.xlabel('April',fontsize=15)
plt.ylabel('percentage',fontsize=15)
plt.legend()
plt.savefig("cali.pdf")
plt.show()

# %%
# NY
sns.set(font_scale=1)
sns.set_style('whitegrid')
plt.figure(figsize=((6,4)))

ax1=plt.plot( [11,13,14,15,16,17,18,19,20],[34.29,38.86,38.97,34.66,34.25,36.22,37.21,41.87,34.62], color='green',label="Positive Response",markersize=12,linewidth=2,linestyle='--' )
ax2=plt.plot( [11,13,14,15,16,17,18,19,20],[42.25,31.18,37.89,38.944,40.60,37.75,45.43,41.87,42.9], color='red',label="Negative Response",linewidth=2,linestyle='--')
ax3=plt.plot( [11,13,14,15,16,17,18,19,20], [9.98215196328404,
 7.149706979222163,
 7.7366746221161495,
 6.941111316226693,
 5.2304505437597095,
 5.167322834645669,
 4.211511464670098,
 3.794342164346655,
 3.4465354387482874], markerfacecolor='blue', marker='o',linewidth=3,markersize=5, color='skyblue', label="Increase in Covid Death cases (%)")
plt.xticks([11,13,14,15,16,17,18,19,20],fontsize=13)
plt.yticks(np.arange(0, 101, 10),fontsize=13)
plt.title(label='NewYork Response for Re-opening of Economy',fontsize=15)
plt.xlabel('April',fontsize=15)
plt.ylabel('percentage',fontsize=15)
plt.legend()
plt.savefig("NY.pdf")
plt.show()

# %%
# Trump
sns.set(font_scale=1)
sns.set_style('whitegrid')
plt.figure(figsize=((6,4)))
ax1=plt.plot( [14,15,16,17,18,19,20],[34.92,37.00,39.02,36.31,36.58,36.62,37.85], color='green',label="Positive Response",markersize=12,linewidth=2,linestyle='--')

ax2=plt.plot( [14,15,16,17,18,19,20], [47.65,46.22,42.83,47.53,47.93,47.13,47.01], color='red',label="Negative Response",linewidth=2,linestyle='--')
ax3=plt.plot( [14,15,16,17,18,19,20], [6.970327483263977,
 10.182248720876148,
 18.912384388072304,
 7.419719218976923,
 11.326763610143011,
 5.008905921088141,
 4.554099203289643], markerfacecolor='blue', marker='o',linewidth=3,markersize=5, color='skyblue', label="Increase in Covid Death cases (%)")
plt.xticks([14,15,16,17,18,19,20],fontsize=13)
plt.yticks(np.arange(0, 101, 10),fontsize=13)
plt.title(label='Trump Popularity',fontsize=15)
plt.xlabel('April',fontsize=15)
plt.ylabel('percentage',fontsize=15)
plt.legend()
plt.savefig("trump_popu.pdf")
plt.show()

# %%
# Boris
sns.set(font_scale=1)
sns.set_style('whitegrid')
plt.figure(figsize=((6,4)))
ax1=plt.plot( [14,15,16,17,18,19,20],[44.65,44.34,47.58,44.66,40.81,40.97,41.89], color='green',label="Positive Response",markersize=12,linewidth=2,linestyle='--')

ax2=plt.plot( [14,15,16,17,18,19,20], [41.94,41.46,35.94,40.17,46.12,46.5,46.25], color='red',label="Negative Response",linewidth=2,linestyle='--')
ax3=plt.plot( [14,15,16,17,18,19,20], [6.756502073124765,
 6.867331626798482,
 6.285619889320228,
 6.691016474976687,
 6.169422390560128,
 6.092206366630077,
 3.8541127780651836], markerfacecolor='blue', marker='o',linewidth=3,markersize=5, color='skyblue', label="Increase in Covid Death cases (%)")
plt.xticks([14,15,16,17,18,19,20],fontsize=13)
plt.yticks(np.arange(0, 101, 10),fontsize=13)
plt.title(label='Boris Johnson Popularity',fontsize=15)
plt.xlabel('April',fontsize=15)
plt.ylabel('percentage',fontsize=15)
plt.legend()
plt.savefig("boris_popu.pdf")
plt.show()

# %%
# modi
sns.set(font_scale=1)
sns.set_style('whitegrid')
plt.figure(figsize=((6,4)))
ax1=plt.plot( [14,15,16,17,18,19,20],[43.99,50.22,49.27,49.87,51.04,50.23,47.01], color='green',label="Positive Response",markersize=12,linewidth=2,linestyle='--')

ax2=plt.plot( [14,15,16,17,18,19,20], [37.97,33.39,35.17,30.14,33.18,33.24,32.97], color='red',label="Negative Response",linewidth=2,linestyle='--')
ax3=plt.plot( [14,15,16,17,18,19,20], [10.064935064935066,
 11.209439528023598,
 9.814323607427056,
 5.555555555555555,
 9.839816933638444,
 5.625,
 7.100591715976331], markerfacecolor='blue', marker='o',linewidth=3,markersize=5, color='skyblue', label="Increase in Covid Death cases (%)")
plt.xticks([14,15,16,17,18,19,20],fontsize=13)
plt.yticks(np.arange(0, 101, 10),fontsize=13)
plt.title(label='Modi Popularity',fontsize=15)
plt.xlabel('April',fontsize=15)
plt.ylabel('percentage',fontsize=15)
plt.legend()
plt.savefig("modi_popu.pdf")
plt.show()
